# %% [markdown]
# <a href="https://colab.research.google.com/github/vikaputri/Moutar/blob/master/Convert_Number_Value_to_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def konversi(x):
    satuan = [' ', 'satu', 'dua', 'tiga', 'empat', 'lima', 'enam', 'tujuh', 'delapan', 'sembilan', 'sepuluh', 'sebelas']
    hasil = ''
    if x <= 0:
        hasil = "Bilangan Haruslah Lebih Dari 0"
    elif x < 12 :
        hasil = satuan[x]
    elif x < 20 :
        hasil = konversi(x-10) + ' belas '
    elif x < 100:
        hasil = konversi(int(x/10)) + '  puluh ' + konversi(x%10)
    elif x < 200 :
        hasil = "seratus " + konversi(x-100)
    elif x < 1000 :
        hasil = konversi(int(x/100)) + ' ratus ' + konversi(x%100)
    elif x < 2000 :
        hasil = "seribu " + konversi(x-1000)
    elif x < 1000000 :
        hasil = konversi(int(x/1000)) + ' ribu ' + konversi(x%1000)
    elif x < 1000000000 :
        hasil = konversi(int(x/1000000)) + ' juta ' + konversi(x%1000000)
    elif x  <= 10000000000 :
        hasil = konversi(int(x/1000000000)) + ' milyar ' + konversi(x%1000000000)
    elif x  >= 1000000000000 :
        hasil = konversi(int(x/1000000000000)) + ' triliun ' + konversi(x%1000000000000)
    return hasil

# %%
a = 9
print('Input :',a)
print('Output :',konversi(a))
# Out:
# Input : 9
# Output : sembilan

# %%
a = 11
print('Input :',a)
print('Output :',konversi(a))
# Out:
# Input : 11
# Output : sebelas

# %%
a = 211232211
print('Input :',a)
print('Output :',konversi(a))
# Out:
# Input : 211232211
# Output : dua ratus sebelas juta dua ratus tiga  puluh dua ribu dua ratus sebelas

# %%
a = int(input())
print('Input :',a)
print('Output :',konversi(a))
# Out:
# 123
# Input : 123
# Output : seratus dua  puluh tiga
